# %% [markdown]
# ### The Python Challenge

# %% [markdown]
# 0

# %%
2**38
# Out:
# 274877906944

# %% [markdown]
# 1

# %%
s = "g fmnc wms bgblr rpylqjyrc gr zw fylb. rfyrq ufyr amknsrcpq ypc dmp. bmgle gr gl zw fylb gq glcddgagclr ylb rfyr'q ufw rfgq rcvr gq qm jmle. sqgle qrpgle.kyicrpylq() gq pcamkkclbcb. lmu ynnjw ml rfc spj." 
url = "map"

# %%
def transformtext(s):
    s2 = [chr(ord(c) + 2) if c != ' ' and c.isalnum() else c for c in s]
    s3 = [chr( ord(c) - 26 ) if ord(c) > 122 else c for c in s2]
    return ''.join(s3)

# %%
print(transformtext(s) + '\n')
print(transformtext(url))
# Out:
# i hope you didnt translate it by hand. thats what computers are for. doing it in by hand is inefficient and that's why this text is so long. using string.maketrans() is recommended. now apply on the url.
#
# ocr

# %% [markdown]
# 2

# %%
with open('ocr.txt', 'r') as f:
    data = f.read()

# %%
''.join([d for d in data if d.isalnum()])
# Out:
# 'equality'

# %% [markdown]
# 3

# %%
import re
with open('equality.txt', 'r') as f:
    data = f.read().replace('\n','')

# %%
RE = r'[^A-Z][A-Z]{3}[a-z]{1}[A-Z]{3}[^A-Z]'
prog = re.compile(RE)

result = prog.findall(data)
answer = ''.join([r[4] for r in result])
print(answer)
# Out:
# linkedlist

# %% [markdown]
# 4

# %%
import urllib.request, re
url = r'http://www.pythonchallenge.com/pc/def/linkedlist.php?nothing='
first = str(12345)
RE = r'[0-9]+'
prog = re.compile(RE)

# %%
numbers = [first]
nr = first
while(True):
    data = urllib.request.urlopen(url + nr)
    html = data.read().decode()
    nr = prog.findall(html)[0]
    numbers += [nr]
    print(str(nr))
#     print(data.info())
# ends at 16044
# http://www.pythonchallenge.com/pc/def/linkedlist.php?nothing=16044
# says 'Yes. Divide by two and keep going.'
# Out:
# 44827
# 45439
# 94485
# 72198
# 80992
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-155-11342477458e> in <module>()
#       2 nr = first
#       3 while(True):
# ----> 4     data = urllib.request.urlopen(url + nr)
#       5     html = data.read().decode()
#       6     nr = prog.findall(html)[0]
#
# c:\python36\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# c:\python36\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# c:\python36\lib\urllib\request.py in _open(self, req, data)
# ...

# %%
nr = str(int(16044/2))
while(True):
    html = urllib.request.urlopen(url + nr).read().decode()
    nr = prog.findall(html)[-1]
    print(nr)
    numbers += [nr]
# Out:
# 25357
# 89879
# 80119
# 50290
# 9297
# 30571
# 7414
# 30978
# 16408
# 80109
# 55736
# 15357
# 80887
# 35014
# 16523
# 50286
# 34813
# 77562
# 54746
# 22680
# 19705
# 77000
# 27634
# 21008
# 64994
# 66109
# 37855
# 36383
# 68548
# 96070
# 83051
# 58026
# 44726
# 35748
# 61287
# 559
# 81318
# 50443
# 1570
# 75244
# 56265
# 17694
# 48033
# 56523
# 51253
# 85750
# 42760
# 11877
# 15962
# 75494
# 87283
# 40396
# 49574
# 82682
# 63579
# 37278
# 53548
# 66081
# 67753
# 56337
# 3356
# 94525
# 89574
# 4413
# 82294
# 56060
# 95493
# 80865
# 66242
# 16065
# 62145
# 23147
# 83763
# 62381
# 76841
# 91706
# 9268
# 64814
# 80809
# 14039
# 73355
# 81905
# 36402
# 27221
# 79607
# 91763
# 11631
# 76396
# 69905
# 11073
# 71281
# 54345
# 19047
# 34376
# 3193
# 74258
# 62712
# 1823
# 21232
# 87890
# 21545
# 37136
# 23060
# 5385
# 4620
# 39111
# 35914
# 60310
# 19178
# 44671
# 45736
# 9216
# 12585
# 11302
# 33096
# 13967
# 57004
# 64196
# 73929
# 24800
# 25081
# 90033
# 45919
# 54827
# 73950
# 56978
# ...

# %% [markdown]
# Finally we arrive at number 66831, which only says 'peak.html'.

# %% [markdown]
# 5

# %%
import pickle
banner = pickle.load(open('banner.p', 'rb'))

# %%
banner
# Out:
# [[(' ', 95)],
#  [(' ', 14), ('#', 5), (' ', 70), ('#', 5), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 15), ('#', 4), (' ', 71), ('#', 4), (' ', 1)],
#  [(' ', 6),
#   ('#', 3),
#   (' ', 6),
#   ('#', 4),
#   (' ', 3),
#   ('#', 3),
#   (' ', 9),
#   ('#', 3),
#   (' ', 7),
#   ('#', 5),
#   (' ', 3),
#   ('#', 3),
#   (' ', 4),
#   ('#', 5),
#   (' ', 3),
#   ('#', 3),
#   (' ', 10),
#   ('#', 3),
#   (' ', 7),
#   ('#', 4),
#   (' ', 1)],
#  [(' ', 3),
#   ('#', 3),
#   (' ', 3),
#   ('#', 2),
#   (' ', 4),
#   ('#', 4),
#   (' ', 1),
#   ('#', 7),
#   (' ', 5),
#   ('#', 2),
#   (' ', 2),
#   ('#', 3),
#   (' ', 6),
#   ('#', 4),
#   (' ', 1),
#   ('#', 7),
# ...

# %%
for b in banner:
    for e in b:
        print(''.join(e[1]*e[0]), end='')
    print()
# Out:
#
#               #####                                                                      #####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#                ####                                                                       ####
#       ###      ####   ###         ###       #####   ###    #####   ###          ###       ####
#    ###   ##    #### #######     ##  ###      #### #######   #### #######     ###  ###     ####
# ...

# %% [markdown]
# 6

# %%
import os, zipfile, sys

folder = r'channel/'
RE = r'[0-9]+'
prog = re.compile(RE)
comments = []
nrs = []

# %%
nr = str(90052)

while True:
    with open(folder + nr + '.txt') as f:
        data = f.read()
        print(data)
        result = prog.findall(data)
        nr = result[-1]
        nrs += [nr]
#         print(nr)
# Out:
# Next nothing is 94191
# Next nothing is 85503
# Next nothing is 70877
# Next nothing is 15409
# Next nothing is 60838
# Next nothing is 80009
# Next nothing is 21347
# Next nothing is 24164
# Next nothing is 13836
# Next nothing is 80123
# Next nothing is 92453
# Next nothing is 69556
# Next nothing is 31491
# Next nothing is 13371
# Next nothing is 88143
# Next nothing is 82593
# Next nothing is 30645
# Next nothing is 88985
# Next nothing is 27190
# Next nothing is 24448
# Next nothing is 37468
# Next nothing is 49892
# Next nothing is 54714
# Next nothing is 75161
# Next nothing is 893
# Next nothing is 57882
# Next nothing is 40033
# Next nothing is 29521
# Next nothing is 5289
# Next nothing is 4701
# Next nothing is 32742
# Next nothing is 18751
# Next nothing is 68586
# Next nothing is 53984
# Next nothing is 52184
# Next nothing is 43807
# Next nothing is 56300
# Next nothing is 97649
# Next nothing is 88244
# Next nothing is 91669
# Next nothing is 88394
# ...

# %%
with zipfile.ZipFile('channel.zip', 'r') as zfile:
    info = zfile.infolist()
comments = {m.filename.split('.')[0] : m.comment for m in info}

# %%
for nr in nrs:
    sys.stdout.write(comments[nr])
# Out:
# ***************************************************************
# ****************************************************************
# **                                                            **
# **   OO    OO    XX      YYYY    GG    GG  EEEEEE NN      NN  **
# **   OO    OO  XXXXXX   YYYYYY   GG   GG   EEEEEE  NN    NN   **
# **   OO    OO XXX  XXX YYY   YY  GG GG     EE       NN  NN    **
# **   OOOOOOOO XX    XX YY        GGG       EEEEE     NNNN     **
# **   OOOOOOOO XX    XX YY        GGG       EEEEE      NN      **
# **   OO    OO XXX  XXX YYY   YY  GG GG     EE         NN      **
# **   OO    OO  XXXXXX   YYYYYY   GG   GG   EEEEEE     NN      **
# **   OO    OO    XX      YYYY    GG    GG  EEEEEE     NN      **
# **                                                            **
# ****************************************************************
#  **************************************************************

# %% [markdown]
# Hockey is not the answer, if you look at the letters inside the large letters, you'll see 'OXYGEN', which is the answer.

# %% [markdown]
# 7

# %%
from PIL import Image
strip = Image.open('strip.png')
width = strip.size[0]
# important: convert to grayscale
strip = strip.convert(mode = 'L')
strip
# Out:
# <PIL.Image.Image image mode=L size=608x9 at 0x19751CFC2B0>

# %%
gscales = []
for x in range(0, width, 7):
    p = strip.getpixel((x,0)) 
    gscales += [p]

# %%
s = ''.join([chr(v) for v in gscales])
print(s)
# Out:
# smart guy, you made it. the next level is [105, 110, 116, 101, 103, 114, 105, 116, 121]

# %%
numbers = [105, 110, 116, 101, 103, 114, 105, 116, 121]
print(''.join([chr(n) for n in numbers]))
# Out:
# integrity

# %% [markdown]
# 8

# %%
import bz2

# %%
un = b'BZh91AY&SYA\xaf\x82\r\x00\x00\x01\x01\x80\x02\xc0\x02\x00 \x00!\x9ah3M\x07<]\xc9\x14\xe1BA\x06\xbe\x084'
pw = b'BZh91AY&SY\x94$|\x0e\x00\x00\x00\x81\x00\x03$ \x00!\x9ah3M\x13<]\xc9\x14\xe1BBP\x91\xf08'
print(un)
print(pw)
# Out:
# b'BZh91AY&SYA\xaf\x82\r\x00\x00\x01\x01\x80\x02\xc0\x02\x00 \x00!\x9ah3M\x07<]\xc9\x14\xe1BA\x06\xbe\x084'
# b'BZh91AY&SY\x94$|\x0e\x00\x00\x00\x81\x00\x03$ \x00!\x9ah3M\x13<]\xc9\x14\xe1BBP\x91\xf08'

# %%
print(bz2.decompress(un))
print(bz2.decompress(pw))
# Out:
# b'huge'
# b'file'

# %% [markdown]
# 9

# %%
first = [146,399,163,403,170,393,169,391,166,386,170,381,170,371,170,355,169,346,167,335,170,329,170,320,170,
310,171,301,173,290,178,289,182,287,188,286,190,286,192,291,194,296,195,305,194,307,191,312,190,316,
190,321,192,331,193,338,196,341,197,346,199,352,198,360,197,366,197,373,196,380,197,383,196,387,192,
389,191,392,190,396,189,400,194,401,201,402,208,403,213,402,216,401,219,397,219,393,216,390,215,385,
215,379,213,373,213,365,212,360,210,353,210,347,212,338,213,329,214,319,215,311,215,306,216,296,218,
290,221,283,225,282,233,284,238,287,243,290,250,291,255,294,261,293,265,291,271,291,273,289,278,287,
279,285,281,280,284,278,284,276,287,277,289,283,291,286,294,291,296,295,299,300,301,304,304,320,305,
327,306,332,307,341,306,349,303,354,301,364,301,371,297,375,292,384,291,386,302,393,324,391,333,387,
328,375,329,367,329,353,330,341,331,328,336,319,338,310,341,304,341,285,341,278,343,269,344,262,346,
259,346,251,349,259,349,264,349,273,349,280,349,288,349,295,349,298,354,293,356,286,354,279,352,268,
352,257,351,249,350,234,351,211,352,197,354,185,353,171,351,154,348,147,342,137,339,132,330,122,327,
120,314,116,304,117,293,118,284,118,281,122,275,128,265,129,257,131,244,133,239,134,228,136,221,137,
214,138,209,135,201,132,192,130,184,131,175,129,170,131,159,134,157,134,160,130,170,125,176,114,176,
102,173,103,172,108,171,111,163,115,156,116,149,117,142,116,136,115,129,115,124,115,120,115,115,117,
113,120,109,122,102,122,100,121,95,121,89,115,87,110,82,109,84,118,89,123,93,129,100,130,108,132,110,
133,110,136,107,138,105,140,95,138,86,141,79,149,77,155,81,162,90,165,97,167,99,171,109,171,107,161,
111,156,113,170,115,185,118,208,117,223,121,239,128,251,133,259,136,266,139,276,143,290,148,310,151,
332,155,348,156,353,153,366,149,379,147,394,146,399]

second = [156,141,165,135,169,131,176,130,187,134,191,140,191,146,186,150,179,155,175,157,168,157,163,157,159,
157,158,164,159,175,159,181,157,191,154,197,153,205,153,210,152,212,147,215,146,218,143,220,132,220,
125,217,119,209,116,196,115,185,114,172,114,167,112,161,109,165,107,170,99,171,97,167,89,164,81,162,
77,155,81,148,87,140,96,138,105,141,110,136,111,126,113,129,118,117,128,114,137,115,146,114,155,115,
158,121,157,128,156,134,157,136,156,136]

# %%
from PIL import Image, ImageDraw
img = Image.open('good.jpg')
print(img.size)
width, height = img.size
# Out:
# (640, 487)

# %%
draw = ImageDraw.Draw(img)
draw.line(first, fill='black', width=2)
draw.line(second, fill='black', width=2)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x487 at 0x19751F9A710>

# %% [markdown]
# bull.html is the right answer

# %% [markdown]
# 10

# %%
a = [1, 11, 21, 1211, 111221]
RE = r'(\w)\1*'
prog = re.compile(RE)

# %%
import re

def saywhatyousee(x):
    x = str(x)
    y = ''
    temp = [match.group() for match in prog.finditer(x)]
    return ''.join([str(len(x)) + x[0] for x in temp])

# %%
x = 1
for i in range(31):
    print(str(i) + ':', len(str(x)))
    x = saywhatyousee(x)
# Out:
# 0: 1
# 1: 2
# 2: 2
# 3: 4
# 4: 6
# 5: 6
# 6: 8
# 7: 10
# 8: 14
# 9: 20
# 10: 26
# 11: 34
# 12: 46
# 13: 62
# 14: 78
# 15: 102
# 16: 134
# 17: 176
# 18: 226
# 19: 302
# 20: 408
# 21: 528
# 22: 678
# 23: 904
# 24: 1182
# 25: 1540
# 26: 2012
# 27: 2606
# 28: 3410
# 29: 4462
# 30: 5808

# %% [markdown]
# 5808 is the correct answer

# %% [markdown]
# 11

# %%
from PIL import Image, ImageEnhance
import numpy as np
import scipy.misc as smp
photo = Image.open('cave.jpg')
width, height = photo.size
print(img.size)
# Out:
# (640, 480)

# %%
for i in range(10):
    for j in range(10):
        print('*' if i%2 == j%2 else '_', end='')            
    print()
# Out:
# *_*_*_*_*_
# _*_*_*_*_*
# *_*_*_*_*_
# _*_*_*_*_*
# *_*_*_*_*_
# _*_*_*_*_*
# *_*_*_*_*_
# _*_*_*_*_*
# *_*_*_*_*_
# _*_*_*_*_*

# %%
img = Image.new( 'RGB', photo.size, "black")
pixels = img.load()

# %%
for i in range(height):
    for j in range(width):
        if i%2 == j%2:
            p = photo.getpixel((j,i))
            pixels[j,i] = p
img
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x1FAB780AF98>

# %%
ImageEnhance.Contrast(image=img).enhance(10)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x1FAB76DD550>

# %% [markdown]
# evil.html is the correct answer

# %% [markdown]
# 12

# %%
with open('evil2.gfx', 'rb') as file:
    bytes = file.read()

# %%
for i in range(5):
    with open('output' + str(i) + '.jpg', 'wb') as out:
        out.write(bytes[i::5])

# %% [markdown]
# Images show 'disproportionality', but ity is crossed out. disproportional is the correct answer

# %% [markdown]
# 13

# %%
import xmlrpc.client
url = r'http://www.pythonchallenge.com/pc/phonebook.php'
proxy = xmlrpc.client.ServerProxy(url)
proxy.system.listMethods()

# %%
proxy.phone('Bert')
# Out:
# '555-ITALY'

# %% [markdown]
# The answer is italy.html

# %% [markdown]
# 14

# %%
from PIL import Image
wire = Image.open('wire.png')
width, height = wire.size

# %%
wire
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=10000x1 at 0x1FDFBD55080>

# %%
img = Image.new( 'RGB', (100,100), "black")
pixels = img.load()

# %%
for i in range(100):
    for j in range(100):
        pixels[i,j] = wire.getpixel((i*j,0))
        
img = img.resize((500,500))
img
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x1FDFBE544A8>

# %%
img = Image.new( 'RGB', (100,100), "black")
pixels = img.load()

length = 100
n = 0
i = 0
j = 0
c = 0

while n < width:
    
    l = 0
    while l < length - 2*c:
#         print('1', (i,j), 'n:', n)
        pixels[i,j] = wire.getpixel((n,0))
        i += 1
        l += 1
        n += 1
    
    i -= 1
    l = 0
    while l < length - 1 - 2*c:
#         print('2', (i,j), 'n:', n)
        pixels[i,j] = wire.getpixel((n,0))
        j += 1
        l += 1
        n += 1

    j -= 1
    l = 0
    while l < length -1 - 2*c:
#         print('3', (i,j), 'n:', n)
        pixels[i,j] = wire.getpixel((n,0))
        i -= 1
        l += 1
        n += 1

    i += 1
    l = 0
    while l < length -2 - 2*c:
#         print('4', (i,j), 'n:', n)
        pixels[i,j] = wire.getpixel((n,0))
        j -= 1
        l += 1
        n += 1
    
    j += 1
    c += 1

# %%
img = img.resize((600,600))
img
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x1FDFBEE70F0>

# %% [markdown]
# cat.html says 'and its name is uzi. you'll hear from him later. '
# uzi.html is the correct answer

# %% [markdown]
# 16

# %%
import calendar
import datetime

for year in range(1006,1996,10):
    if calendar.isleap(year) and datetime.datetime(year, 1, 1).weekday() == 3: 
#     datetime.datetime(year, 1, 1).weekday() == 3:       
        print(datetime.datetime(year, 1, 1))
# Out:
# 1176-01-01 00:00:00
# 1356-01-01 00:00:00
# 1576-01-01 00:00:00
# 1756-01-01 00:00:00
# 1976-01-01 00:00:00

# %% [markdown]
# Clues:
# 'He ain't the youngest', use the second-to-last one
# 'Buy flower for tomorrow', don't use the 26th, but the 27th instead.
#
# 27 january 1756 happens to be the birthday of Mozart. Mozart.html is the correct answer.

# %% [markdown]
# 17

# %%
from PIL import Image
from collections import deque
photo = Image.open('mozart.gif')
width, height = photo.size
print(img.size)
# Out:
# (600, 600)

# %%
for i in range(60):
    for j in range(60,90):
        print('{:3} '.format(photo.getpixel((j,i))), end='')
    print()
# Out:
#  24  24  54  94  84  24  90  95  17  88  60  60  23  54  84 125  95  47 131  96  96  95  16  22 124  24  16  16 125  18
# 136  60  23 126  88  66  82  60 136  16  90  94  24  54  18  53  60  90  96  24  60  53 102  17  54  84  60  23  16  59
#  95  17  48  95  60  22  88  47  17  95  58  52  22 119  54 131  18  84  16  88  94  11  58  18  88  94  60  59  11  17
#  59  60  30  89 125  90  18  59  96  18  48  23  83  95  54  22  53  94  17  60  60  96  95  60  91  60  90  95  47 100
#  88  60  18  59  89  58  60   9  22  24  83 102  24  94 120  60  96  22  52  60  90  17  54  55  88  17  60  58  16 125
#  96  88  18 131  60  96  95  23  95  54  59  47  88 102  52  91  23  16  48  17  18  90  58  59  18  88  61  18  60   9
#  18  90  83  95  17  88  54  24  54  89  88  88  24  96  11  16  89  60  88  88  52  16  54  96  94  59  16  48  82  61
#  94  60  60  47  54  59  12  54  54  84  95  89  90  48  96  24  60 138  96  23  55  24  82  23  96  83  24 138  24 130
# ...

# %%
img = Image.new( 'RGB', photo.size, "black")
pixels = img.load()

for i in range(height):
    row = deque([photo.getpixel((j,i)) for j in range(width)])
    x = 0
    found = False
    while not found:
        if row[x] == 195:
            found = True
        else:
            x += 1
#     print('first occurence on', x)
    row.rotate(1 - x)
#     print([row[i] for i in range(10)])
    for j in range(width):
        pixels[j,i] = row[j]

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x1FDFC0B2F98>

# %% [markdown]
# romance.html is the correct answer

# %% [markdown]
# 17

# %%
import requests
import bz2
from urllib.parse import unquote_to_bytes
import xmlrpc.client
url = r'http://www.pythonchallenge.com/pc/def/linkedlist.php?busynothing=' #NOTE: _busy_nothing
first = '12345'
RE = r'[0-9]+'
prog = re.compile(RE)

# %%
cookies = []
numbers = [first]
nr = first
while(True):
    data = requests.get(url + nr)
    numbers += [nr]
    print(data.text)
    if data.cookies:
        for cookie in data.cookies:
            cookies += [cookie]
    nr = prog.findall(data.text)[-1]
# Out:
# If you came here from level 4 - go back!<br>You should follow the obvious chain...<br><br>and the next busynothing is 44827
# and the next busynothing is 45439
# and the next busynothing is 94485
# and the next busynothing is 72198
# and the next busynothing is 80992
# and the next busynothing is 8880
# and the next busynothing is 40961
# and the next busynothing is 58765
# and the next busynothing is 46561
# and the next busynothing is 13418
# and the next busynothing is 41954
# and the next busynothing is 46782
# and the next busynothing is 92730
# and the next busynothing is 89229
# and the next busynothing is 25646
# and the next busynothing is 74288
# and the next busynothing is 25945
# and the next busynothing is 39876
# and the next busynothing is 8498
# and the next busynothing is 34684
# and the next busynothing is 62316
# and the next busynothing is 71331
# and the next busynothing is 59717
# and the next busynothing is 76893
# and the next busynothing is 44091
# ...

# %%
s = b''.join([unquote_to_bytes(c.value if c.value != '+' else ' ') for c in cookies])
print(s)
# Out:
# b'BZh91AY&SY\x94:\xe2I\x00\x00!\x19\x80P\x81\x11\x00\xafg\x9e\xa0 \x00hE=M\xb5#\xd0\xd4\xd1\xe2\x8d\x06\xa9\xfa&S\xd4\xd3!\xa1\xeai7h\x9b\x9a+\xbf`"\xc5WX\xe1\xadL\x80\xe8V<\xc6\xa8\xdbH&32\x18\xa8x\x01\x08!\x8dS\x0b\xc8\xaf\x96KO\xca2\xb0\xf1\xbd\x1du\xa0\x86\x05\x92s\xb0\x92\xc4Bc\xf1w$S\x85\t\tC\xae$\x90'

# %%
t = bz2.decompress(s)
print(t)
# Out:
# b'is it the 26th already? call his father and inform him that "the flowers are on their way". he\'ll understand.'

# %%
url = r'http://www.pythonchallenge.com/pc/phonebook.php'
proxy = xmlrpc.client.ServerProxy(url)
proxy.system.listMethods()
# Out:
# ['phone',
#  'system.listMethods',
#  'system.methodHelp',
#  'system.methodSignature',
#  'system.multicall',
#  'system.getCapabilities']

# %%
proxy.phone('Leopold')
# Out:
# '555-VIOLIN'

# %% [markdown]
# http://www.pythonchallenge.com/pc/return/violin.html

# %% [markdown]
# http://www.pythonchallenge.com/pc/stuff/violin.php

# %% [markdown]
# Stuck, copy-paste van the python challenge solutions:

# %%
from urllib.request import Request, urlopen
from urllib.parse import quote_plus

url = "http://www.pythonchallenge.com/pc/stuff/violin.php"
msg = "the flowers are on their way"
req = Request(url, headers = { "Cookie": "info=" + quote_plus(msg)})

print(urlopen(req).read().decode())
# Out:
# <html>
# <head>
#   <title>it's me. what do you want?</title>
#   <link rel="stylesheet" type="text/css" href="../style.css">
# </head>
# <body>
# 	<br><br>
# 	<center><font color="gold">
# 	<img src="leopold.jpg" border="0"/>
# <br><br>
# oh well, don't you dare to forget the balloons.</font>
# </body>
# </html>

# %% [markdown]
# balloons.html is the correct answer

# %% [markdown]
# 18

# %%
from PIL import Image
import difflib
d = difflib.Differ()
full = Image.open('balloons.jpg')
width, height = full.size
half = int(width/2)

# %%
full.size
# Out:
# (750, 335)

# %%
img = Image.new( 'RGB', (int(width/2),height), "black")
pixels = img.load()

# %%
for i in range(height):
    for j in range(half):
        a = full.getpixel((j,i))
        b = full.getpixel((half + j,i))
        pixels[j,i] = tuple([x - y for x, y in zip(a,b)])

# %%
img.resize((1000,1000))
img
# Out:
# <PIL.Image.Image image mode=RGB size=375x335 at 0x27C7C543CC0>

# %%
for i in range(10):
    for j in range(10):
        print('({:2},{:2},{:2})'.format(*img.getpixel((j,i))), end = '')
    print()
# Out:
# (60,57,50)(61,57,53)(59,58,55)(63,60,60)(64,63,63)(65,63,66)(64,61,64)(65,61,67)(66,65,70)(71,67,66)
# (65,61,56)(70,68,63)(69,68,65)(69,66,66)(68,67,67)(69,67,68)(67,65,68)(67,67,69)(66,65,71)(70,64,62)
# (68,67,61)(76,73,70)(71,71,69)(68,68,67)(70,70,69)(73,72,72)(72,72,74)(68,68,70)(73,72,76)(74,67,65)
# (73,76,68)(69,69,65)(66,69,66)(66,68,65)(70,70,70)(73,73,74)(72,72,73)(68,69,70)(74,75,76)(76,70,68)
# (66,69,66)(63,68,64)(66,71,69)(69,72,71)(71,72,72)(69,70,70)(68,68,68)(71,74,73)(63,67,68)(71,65,63)
# (64,70,68)(65,71,69)(65,71,71)(68,73,71)(69,74,72)(68,71,70)(66,71,69)(72,77,75)(75,80,78)(76,72,69)
# (70,80,79)(64,72,72)(63,72,69)(65,74,71)(68,74,72)(66,72,70)(66,70,69)(70,74,73)(61,67,65)(81,78,73)
# (57,66,68)(65,72,74)(67,74,74)(69,76,76)(69,75,73)(63,70,65)(61,68,63)(66,73,68)(70,76,74)(68,64,62)
# (74,83,86)(64,73,76)(60,70,69)(61,69,69)(64,70,70)(64,70,68)(67,73,69)(69,75,71)(65,71,67)(71,69,68)
# ...

# %% [raw]
# Difference is in brightness. Going to brightness.html gives the same page, but there's comment that says
# <!-- maybe consider deltas.gz -->

# %%
with open('delta.txt', 'r') as file:
    ddata = file.read()

# %%
srows = ddata.splitlines()

# %%
left = [e[:53] for e in srows]
right = [e[56:] for e in srows]

# %%
result = list(d.compare(left,right))

# %%
result
# Out:
# ['  89 50 4e 47 0d 0a 1a 0a 00 00 00 0d 49 48 44 52 00 00',
#  '  02 8a 00 00 00 c8 08 02 00 00 00 e0 19 57 95 00 00 00',
#  '  09 70 48 59 73 00 00 0b 13 00 00 0b 13 01 00 9a 9c 18',
#  '  00 00 00 07 74 49 4d 45 07 d5 05 07 0c 18 32 98 c6 a0',
#  '  48 00 00 00 1d 74 45 58 74 43 6f 6d 6d 65 6e 74 00 43',
#  '  72 65 61 74 65 64 20 77 69 74 68 20 54 68 65 20 47 49',
#  '  4d 50 ef 64 25 6e 00 00 20 00 49 44 41 54 78 da ec bd',
#  '  57 93 9c 47 92 25 7a 3c c4 a7 53 55 96 42 01 20 9b 6c',
#  '  31 b3 63 bb 4f fb ff 1f ee d3 bd 2f d7 ae d9 8e d8 e9',
#  '  ee 69 92 0d 5d ba b2 52 7d 22 22 fc 3e 78 e6 c7 6a 28',
#  '  42 16 0a d8 38 06 a3 91 00 58 55 f9 89 70 f7 e3 c7 8f',
#  '  03 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11',
#  '  11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11',
#  '  11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11',
#  '  11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11',
#  '  11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11 11',
# ...

# %%
f  = open("f.png", "wb")
f1 = open("f1.png", "wb")
f2 = open("f2.png", "wb")

for row in result:
    if row[0] == '+':
        f1.write(bytes([int(a,16) for a in row[2:].split(' ') if a]))
    elif row[0] == '-':
        f2.write(bytes([int(a,16) for a in row[2:].split(' ') if a]))
    else:
        f.write(bytes( [int(a,16) for a in row[2:].split(' ') if a])) 
    
f.close()
f1.close()
f2.close()

# %% [markdown]
# page can be found at http://www.pythonchallenge.com/pc/hex/bin.html
# user: butter
# pass: fly

# %% [markdown]
# 19

# %%
import base64, wave

# %%
with open('b64', 'r') as b64:
    data = b64.read().splitlines()[3:]

# %%
b = bytes(''.join(data), 'ascii')

# %%
b2 = base64.b64decode(b)

# %%
with open('out.wav', 'wb') as outwav:
    outwav.write(b2)

# %%
w = wave.open('indian.wav', 'rb')

h = wave.open("result.wav", "wb")

# print(w.getnchannels())
# print(w.getsampwidth())
# print(w.getframerate())
h.setnchannels(w.getnchannels())
h.setsampwidth(w.getsampwidth()//2)
h.setframerate(w.getframerate()*2)
frames = w.readframes(w.getnframes())
wave.big_endiana = 1
h.writeframes(frames)

w.close()
h.close()

# %% [markdown]
# http://www.pythonchallenge.com/pc/hex/idiot2.html

# %% [markdown]
# 20
